# %% [markdown]
# # Spotify Regression Problem 2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("data/CS98XRegressionTrain.csv", encoding='utf-8', index_col=0)
df_test = pd.read_csv("data/CS98XRegressionTest.csv", encoding='utf-8', index_col=0)

df_train
# Out:
#                                            title            artist  \
# Id
# 1                                   My Happiness    Connie Francis
# 2                               Unchained Melody   The Teddy Bears
# 3                          How Deep Is Your Love          Bee Gees
# 4                                  Woman in Love  Barbra Streisand
# 5    Goodbye Yellow Brick Road - Remastered 2014        Elton John
# ..                                           ...               ...
# 449                               But Not For Me   Ella Fitzgerald
# 450                                    Surf City        Jan & Dean
# 451                                      Dilemma             Nelly
# 452                             It's Gonna Be Me            *NSYNC
# 453                              In The Army Now        Status Quo
#
#               top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# Id
# 1       adult standards  1996  107    31    45  -8    13   28  150     75
# ...

# %%
df_test
# Out:
#                                                  title                artist  \
# Id
# 454                                            Pump It   The Black Eyed Peas
# 455  Circle of Life - From "The Lion King"/Soundtra...            Elton John
# 456             We Are The Champions - Remastered 2011                 Queen
# 457                              Insomnia - Radio Edit             Faithless
# 458                                This Eve of Parting         John Hartford
# ..                                                 ...                   ...
# 563                                         Candy Shop               50 Cent
# 564                Dragostea Din Tei - Italian Version                O-Zone
# 565                          Big Poppa - 2005 Remaster  The Notorious B.I.G.
# 566                       YMCA - Original Version 1978        Village People
# 567                                 Livin' On A Prayer              Bon Jovi
#
# ...
