# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math

# %%
df = pd.read_csv('hd_mortalitybyca.csv')
df
# Out:
#        Year         CA CAQF      AgeGroup AgeGroupQF      Sex SexQF  \
# 0      2012  S92000003    d    0-44 years        NaN    Males   NaN
# 1      2012  S92000003    d    0-44 years        NaN  Females   NaN
# 2      2012  S92000003    d   45-64 years        NaN    Males   NaN
# 3      2012  S92000003    d   45-64 years        NaN  Females   NaN
# 4      2012  S92000003    d   65-74 years        NaN    Males   NaN
# ...     ...        ...  ...           ...        ...      ...   ...
# 17815  2021  S12000050  NaN    0-44 years        NaN      All     d
# 17816  2021  S12000050  NaN   45-64 years        NaN      All     d
# 17817  2021  S12000050  NaN   65-74 years        NaN      All     d
# 17818  2021  S12000050  NaN  75plus years        NaN      All     d
# 17819  2021  S12000050  NaN           All          d      All     d
#
#                     Diagnosis  NumberOfDeaths NumberOfDeathsQF   CrudeRate  \
# 0      Coronary Heart Disease            86.0              NaN    5.880185
# 1      Coronary Heart Disease            25.0              NaN    1.702501
# 2      Coronary Heart Disease           906.0              NaN  127.286342
# 3      Coronary Heart Disease           226.0              NaN   30.331051
# 4      Coronary Heart Disease          1023.0              NaN  428.071086
# ...                       ...             ...              ...         ...
# 17815           Heart Failure             0.0              NaN    0.000000
# 17816           Heart Failure             NaN                c         NaN
# 17817           Heart Failure             NaN                c         NaN
# 17818           Heart Failure             NaN                c         NaN
# 17819           Heart Failure            20.0              NaN    5.858231
#
#       CrudeRateQF        EASR
# 0             NaN    6.172823
# 1             NaN    1.714014
# 2             NaN  129.121787
# 3             NaN   30.834745
# 4             NaN  439.227442
# ...           ...         ...
# 17815         NaN    0.000000
# 17816           c    2.158390
# 17817           c    9.241572
# 17818           c   52.936148
# 17819         NaN    6.306592
#
# [17820 rows x 13 columns]

# %%
df = df.drop(['CAQF', 'AgeGroupQF', 'SexQF', 'NumberOfDeathsQF', 'CrudeRateQF'], axis=1)
df
# Out:
#        Year         CA      AgeGroup      Sex               Diagnosis  \
# 0      2012  S92000003    0-44 years    Males  Coronary Heart Disease
# 1      2012  S92000003    0-44 years  Females  Coronary Heart Disease
# 2      2012  S92000003   45-64 years    Males  Coronary Heart Disease
# 3      2012  S92000003   45-64 years  Females  Coronary Heart Disease
# 4      2012  S92000003   65-74 years    Males  Coronary Heart Disease
# ...     ...        ...           ...      ...                     ...
# 17815  2021  S12000050    0-44 years      All           Heart Failure
# 17816  2021  S12000050   45-64 years      All           Heart Failure
# 17817  2021  S12000050   65-74 years      All           Heart Failure
# 17818  2021  S12000050  75plus years      All           Heart Failure
# 17819  2021  S12000050           All      All           Heart Failure
#
#        NumberOfDeaths   CrudeRate        EASR
# 0                86.0    5.880185    6.172823
# 1                25.0    1.702501    1.714014
# 2               906.0  127.286342  129.121787
# 3               226.0   30.331051   30.834745
# 4              1023.0  428.071086  439.227442
# ...               ...         ...         ...
# 17815             0.0    0.000000    0.000000
# 17816             NaN         NaN    2.158390
# 17817             NaN         NaN    9.241572
# 17818             NaN         NaN   52.936148
# 17819            20.0    5.858231    6.306592
#
# [17820 rows x 8 columns]

# %%
df[df.isnull().any(axis=1)]
df2 = df.dropna()
df2
# Out:
#        Year         CA     AgeGroup      Sex               Diagnosis  \
# 0      2012  S92000003   0-44 years    Males  Coronary Heart Disease
# 1      2012  S92000003   0-44 years  Females  Coronary Heart Disease
# 2      2012  S92000003  45-64 years    Males  Coronary Heart Disease
# 3      2012  S92000003  45-64 years  Females  Coronary Heart Disease
# 4      2012  S92000003  65-74 years    Males  Coronary Heart Disease
# ...     ...        ...          ...      ...                     ...
# 17807  2021  S12000048          All      All           Heart Failure
# 17809  2021  S12000049   0-44 years      All           Heart Failure
# 17813  2021  S12000049          All      All           Heart Failure
# 17815  2021  S12000050   0-44 years      All           Heart Failure
# 17819  2021  S12000050          All      All           Heart Failure
#
#        NumberOfDeaths   CrudeRate        EASR
# 0                86.0    5.880185    6.172823
# 1                25.0    1.702501    1.714014
# 2               906.0  127.286342  129.121787
# 3               226.0   30.331051   30.834745
# 4              1023.0  428.071086  439.227442
# ...               ...         ...         ...
# 17807            12.0    7.801833    6.628059
# 17809             0.0    0.000000    0.000000
# 17813            41.0    6.455371    9.521978
# 17815             0.0    0.000000    0.000000
# 17819            20.0    5.858231    6.306592
#
# [7262 rows x 8 columns]

# %%
df_2022 = df2[df2['Year'] == 2021] 
df2_age = df_2022[df_2022["AgeGroup"].str.contains("All") == False]
df2_age = df2_age[df2_age["AgeGroup"].str.contains("under75 years") == False] 
df2_age = df2_age[df2_age["Sex"].str.contains("Males") == False]
df2_age = df2_age[df2_age["Sex"].str.contains("Females") == False] 
df2_age
# Out:
#        Year         CA      AgeGroup  Sex               Diagnosis  \
# 5743   2021  S92000003    0-44 years  All  Coronary Heart Disease
# 5744   2021  S92000003   45-64 years  All  Coronary Heart Disease
# 5745   2021  S92000003   65-74 years  All  Coronary Heart Disease
# 5746   2021  S92000003  75plus years  All  Coronary Heart Disease
# 5779   2021  S12000013    0-44 years  All  Coronary Heart Disease
# ...     ...        ...           ...  ...                     ...
# 17797  2021  S12000047    0-44 years  All           Heart Failure
# 17803  2021  S12000048    0-44 years  All           Heart Failure
# 17805  2021  S12000048   65-74 years  All           Heart Failure
# 17809  2021  S12000049    0-44 years  All           Heart Failure
# 17815  2021  S12000050    0-44 years  All           Heart Failure
#
#        NumberOfDeaths   CrudeRate        EASR
# 5743             92.0    3.155100    3.415911
# 5744           1241.0   83.281604   81.819762
# 5745           1531.0  257.061208  261.401228
# 5746           4184.0  874.795884  936.178926
# 5779              0.0    0.000000    0.000000
# ...               ...         ...         ...
# 17797             0.0    0.000000    0.000000
# 17803             0.0    0.000000    0.000000
# 17805             0.0    0.000000    0.000000
# 17809             0.0    0.000000    0.000000
# 17815             0.0    0.000000    0.000000
#
# [93 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
sns.set_theme(style="white", palette = 'muted')
chd = df2_age[['AgeGroup', 'NumberOfDeaths']]
chd = chd.groupby(['AgeGroup'], as_index=False).sum()
chd

def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{:.1f}%'.format(pct, v=val)
        return my_format

percentage = chd['NumberOfDeaths'].value_counts()
plt.pie(chd['NumberOfDeaths'], labels = chd['AgeGroup'], autopct=autopct_format(percentage))
plt.axis('equal')
plt.title('Number of Deaths by age group for \n patients with Heart Disease', fontsize = 14)
plt.show()
